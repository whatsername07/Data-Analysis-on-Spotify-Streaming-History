# %% [markdown]
# # Spotify History Data Cleaning
# ## Loading into dataframe

# %%
import pandas as pd

fullHistory = pd.read_csv("./Spotify Extended Streaming History/full-history.csv")
fullHistory.sample(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20372\1800744322.py:3: DtypeWarning: Columns (0: episode_name, 1: episode_show_name, 2: spotify_episode_uri) have mixed types. Specify dtype option on import or set low_memory=False.
#   fullHistory = pd.read_csv("./Spotify Extended Streaming History/full-history.csv")
#                           ts                 platform  ms_played conn_country  \
# 282011  2021-07-23T15:00:31Z    iOS 14.6 (iPhone13,2)        882           GB
# 65714   2022-12-05T19:57:58Z                      ios      11424           GB
# 136829  2024-07-09T13:19:03Z                      ios     362293           GB
# 215077  2020-05-04T11:05:01Z   iOS 12.4.5 (iPhone7,2)     193000           GB
# 289786  2021-08-27T09:40:51Z  iOS 14.7.1 (iPhone13,2)     154799           GB
# 143675  2024-09-04T16:07:23Z                      ios       1184           GB
# 42555   2022-06-20T16:47:35Z    iOS 15.5 (iPhone13,2)       3482           GB
# 76071   2023-02-24T08:39:02Z                      ios      11958           GB
# 280776  2021-07-16T16:54:47Z    iOS 14.6 (iPhone13,2)     617746           GB
# 58308   2022-10-03T20:20:25Z  iOS 15.6.1 (iPhone13,2)     132773           GB
#
#               master_metadata_track_name master_metadata_album_artist_name  \
# 282011  See You Again (feat. Kali Uchis)                Tyler, The Creator
# 65714                               Kids                               PUP
# 136829                   My Jamaican Guy                       Grace Jones
# 215077                        Brain Stew                         Green Day
# 289786                              Itch                               Ewy
# 143675                  Two Worlds Apart                       Little Simz
# 42555                              Bruja                              Arca
# 76071                           Ceremony                          Skrillex
# 280776          Viðrar vel til loftárása                         Sigur Rós
# 58308                     Brand New City                            Mitski
#
#        master_metadata_album_album_name                     spotify_track_uri  \
# 282011                       Flower Boy  spotify:track:7KA4W4McWYRpgf0fWsJZWB
# 65714                      Morbid Stuff  spotify:track:6Dgix2xCbnqigfrjulm24R
# 136829                   Living My Life  spotify:track:7zcC5yZZp1IKnI73ztsIaE
# 215077                        Insomniac  spotify:track:1nLnpLXvl68RZCSjfkyiaa
# 289786                    World Is Mine  spotify:track:2pipmcMfejCPuOAwPoiFQQ
# 143675   Sometimes I Might Be Introvert  spotify:track:34qvgmIagzNQdZTRL2poiv
# 42555                          KicK iii  spotify:track:4DbRtnuP6eyQSGXbquLRv0
# 76071               Don’t Get Too Close  spotify:track:4DmqWDZUtoxBX7wg9eCgzF
# 280776                    Ágætis byrjun  spotify:track:1blbT2vGiqxICPoyxzfVn1
# 58308                              Lush  spotify:track:47k7FCxk7ylTwKCnJ3QTVc
#
#        episode_name episode_show_name  ... audiobook_uri  \
# 282011          NaN               NaN  ...           NaN
# 65714           NaN               NaN  ...           NaN
# 136829          NaN               NaN  ...           NaN
# 215077          NaN               NaN  ...           NaN
# 289786          NaN               NaN  ...           NaN
# 143675          NaN               NaN  ...           NaN
# 42555           NaN               NaN  ...           NaN
# 76071           NaN               NaN  ...           NaN
# 280776          NaN               NaN  ...           NaN
# 58308           NaN               NaN  ...           NaN
#
#         audiobook_chapter_uri  audiobook_chapter_title  reason_start  \
# 282011                    NaN                      NaN       playbtn
# 65714                     NaN                      NaN        fwdbtn
# 136829                    NaN                      NaN        fwdbtn
# 215077                    NaN                      NaN     trackdone
# 289786                    NaN                      NaN     trackdone
# 143675                    NaN                      NaN      clickrow
# 42555                     NaN                      NaN      clickrow
# 76071                     NaN                      NaN        fwdbtn
# 280776                    NaN                      NaN     trackdone
# 58308                     NaN                      NaN        fwdbtn
#
#         reason_end shuffle skipped  offline  offline_timestamp  incognito_mode
# 282011     endplay    True   False    False                NaN           False
# 65714      endplay    True    True    False       1.670270e+09           False
# 136829   trackdone    True   False    False       1.720531e+09           False
# 215077   trackdone   False   False    False                NaN           False
# 289786   trackdone    True   False    False                NaN           False
# 143675     endplay    True    True    False       1.725466e+09           False
# 42555      endplay   False   False     True       1.655744e+12           False
# 76071       fwdbtn    True    True    False       1.677228e+09           False
# 280776   trackdone   False   False    False                NaN           False
# 58308    trackdone    True   False    False                NaN           False
#
# [10 rows x 22 columns]

# %%
# drop all podcast and audiobook rows
fullHistory = fullHistory[~fullHistory["episode_name"].notna()]
fullHistory = fullHistory[~fullHistory["audiobook_uri"].notna()]

# drop podcasts and audiobooks columns
fullHistory = fullHistory.drop(
    columns=[
        "episode_name",
        "episode_show_name",
        "spotify_episode_uri",
        "audiobook_title",
        "audiobook_chapter_uri",
        "audiobook_uri",
        "audiobook_chapter_title",
    ]
)

# %%
fullHistory.sample(10)
# Out:
#                           ts                 platform  ms_played conn_country  \
# 10428   2019-04-12T17:31:15Z     iOS 12.2 (iPhone6,2)        696           GB
# 15988   2021-12-23T19:36:21Z  iOS 15.1.1 (iPhone13,2)       1950           GB
# 312995  2021-12-19T15:18:55Z  iOS 15.1.1 (iPhone13,2)        534           GB
# 107359  2023-11-22T00:08:16Z                      ios       1787           GB
# 232698  2020-11-17T23:52:03Z   iOS 12.4.8 (iPhone7,2)     253586           GB
# 149107  2024-10-30T18:33:45Z                      ios     146225           GB
# 201680  2026-01-18T15:12:35Z                      ios       2113           CH
# 895     2017-05-31T08:17:57Z      iOS 9.3.5 (iPad2,1)       3459           GB
# 277097  2021-07-02T17:19:50Z    iOS 14.6 (iPhone13,2)       8223           GB
# 179493  2019-06-21T14:47:36Z   iOS 12.3.1 (iPhone6,2)     197573           GB
#
#        master_metadata_track_name master_metadata_album_artist_name  \
# 10428             Young Volcanoes                      Fall Out Boy
# 15988                  All I Need                         Radiohead
# 312995            Heaven and Hell                        Kanye West
# 107359    I Don't Love Me Anymore             Oneohtrix Point Never
# 232698                        505                    Arctic Monkeys
# 149107                      crush                           2hollis
# 201680                 Fire Dance                   Dizzy Gillespie
# 895                      Rich Boy                          Galantis
# 277097                   45 SMOKE                          slowthai
# 179493    Talk (feat. Disclosure)                            Khalid
#
#        master_metadata_album_album_name                     spotify_track_uri  \
# 10428                Save Rock And Roll  spotify:track:4yXNMbZrsFJbPTH0WfhwEB
# 15988                       In Rainbows  spotify:track:5Qv2Nby1xTr9pQyjkrc94J
# 312995                            Donda  spotify:track:2Y40huo5ewaKYxsFintYtF
# 107359      Magic Oneohtrix Point Never  spotify:track:1VyvcAAHK9sbKi1ZC34IBb
# 232698        Favourite Worst Nightmare  spotify:track:0BxE4FqsDD1Ot4YuBXwAPp
# 149107                            crush  spotify:track:7oUMu1A4dgci1erq7TfeBi
# 201680                        Free Ride  spotify:track:3lhNPeZgnuUigHq11zA0uS
# 895                            Rich Boy  spotify:track:0K7Dd9DP6fvOl0mrlX0aUa
# 277097                            TYRON  spotify:track:52dZyvQ3mSuS76t9Dok4hq
# 179493                      Free Spirit  spotify:track:6TqXcAFInzjp0bODyvrWEq
#
#        reason_start reason_end  shuffle  skipped  offline  offline_timestamp  \
# 10428      clickrow    endplay     True    False    False                NaN
# 15988       playbtn    endplay     True    False    False                NaN
# 312995       fwdbtn     fwdbtn    False    False    False                NaN
# 107359     clickrow    endplay     True     True    False       1.700612e+09
# 232698    trackdone  trackdone     True    False    False                NaN
# 149107       fwdbtn  trackdone     True    False    False       1.730313e+09
# 201680       fwdbtn     fwdbtn     True     True    False       1.768749e+09
# 895          fwdbtn     fwdbtn     True    False    False                NaN
# 277097    trackdone    endplay     True    False    False                NaN
# 179493    trackdone  trackdone     True    False     True       1.561117e+12
#
#         incognito_mode
# 10428            False
# 15988            False
# 312995           False
# 107359           False
# 232698           False
# 149107           False
# 201680           False
# 895              False
# 277097           False
# 179493           False

# %%
# drop irrelevant columns
fullHistory = fullHistory.drop(
    columns=[
        "platform",
        "spotify_track_uri",
        "shuffle",
        "offline",
        "offline_timestamp",
        "incognito_mode"
    ]
)

# %%
fullHistory[fullHistory['master_metadata_track_name'] == "Lover, You Should've Come Over"]
# Out:
#                           ts  ms_played conn_country  \
# 65485   2022-12-04T01:06:48Z     404213           GB
# 65486   2022-12-04T01:14:30Z     404213           GB
# 65492   2022-12-04T11:05:45Z     404213           GB
# 65495   2022-12-04T11:18:05Z     404213           GB
# 65496   2022-12-04T11:26:30Z     404213           GB
# ...                      ...        ...          ...
# 125539  2024-04-20T16:34:50Z       2229           GB
# 133601  2024-06-13T15:57:58Z        207           GB
# 149181  2024-10-31T15:19:51Z       1393           GB
# 149210  2024-10-31T17:37:30Z     248446           GB
# 154079  2024-12-20T13:35:11Z       6757           GB
#
#             master_metadata_track_name master_metadata_album_artist_name  \
# 65485   Lover, You Should've Come Over                      Jeff Buckley
# 65486   Lover, You Should've Come Over                      Jeff Buckley
# 65492   Lover, You Should've Come Over                      Jeff Buckley
# 65495   Lover, You Should've Come Over                      Jeff Buckley
# 65496   Lover, You Should've Come Over                      Jeff Buckley
# ...                                ...                               ...
# 125539  Lover, You Should've Come Over                      Jeff Buckley
# 133601  Lover, You Should've Come Over                      Jeff Buckley
# 149181  Lover, You Should've Come Over                      Jeff Buckley
# 149210  Lover, You Should've Come Over                      Jeff Buckley
# 154079  Lover, You Should've Come Over                      Jeff Buckley
#
#        master_metadata_album_album_name reason_start reason_end  skipped
# 65485                             Grace       fwdbtn  trackdone    False
# 65486                             Grace    trackdone  trackdone    False
# 65492                             Grace       fwdbtn  trackdone    False
# 65495                             Grace     clickrow  trackdone    False
# 65496                             Grace    trackdone  trackdone    False
# ...                                 ...          ...        ...      ...
# 125539                            Grace     clickrow    endplay     True
# 133601                            Grace    trackdone     fwdbtn     True
# 149181                            Grace       fwdbtn     fwdbtn     True
# 149210                            Grace    trackdone     fwdbtn     True
# 154079                            Grace      playbtn    endplay     True
#
# [103 rows x 9 columns]
