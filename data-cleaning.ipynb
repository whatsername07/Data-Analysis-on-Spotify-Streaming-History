# %% [markdown]
# # Spotify History Data Cleaning
# ## Loading into dataframe

# %%
import pandas as pd

fullHistory = pd.read_csv("./Spotify Extended Streaming History/full-history.csv")
fullHistory.sample(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20548\1800744322.py:3: DtypeWarning: Columns (0: episode_name, 1: episode_show_name, 2: spotify_episode_uri) have mixed types. Specify dtype option on import or set low_memory=False.
#   fullHistory = pd.read_csv("./Spotify Extended Streaming History/full-history.csv")
#                           ts                 platform  ms_played conn_country  \
# 290288  2021-08-28T23:09:05Z  iOS 14.7.1 (iPhone13,2)        255           GB
# 76864   2023-03-03T15:43:36Z                      ios      90702           GB
# 122359  2024-03-30T06:20:22Z                      ios      64885           GB
# 30514   2022-03-26T14:20:46Z  iOS 15.3.1 (iPhone13,2)     230197           GB
# 72465   2023-01-27T18:05:43Z                      ios      86146           GB
# 309237  2021-11-25T08:08:18Z    iOS 15.1 (iPhone13,2)        696           GB
# 174470  2025-08-08T08:48:17Z                      ios     322419           GB
# 194425  2025-09-28T20:12:20Z                      ios       3871           GB
# 292824  2021-09-06T22:04:58Z  iOS 14.7.1 (iPhone13,2)     234475           GB
# 236951  2021-01-02T19:27:38Z   iOS 12.4.9 (iPhone7,2)     235866           GB
#
#                    master_metadata_track_name  \
# 290288                    THE BENDS! - OG MIX
# 76864                                     Yum
# 122359                           Neon Kitchen
# 30514   The Place Where He Inserted the Blade
# 72465                  1979 - Remastered 2012
# 309237                  Frontier Psychiatrist
# 174470                          Mental Health
# 194425                               FLATLINE
# 292824                  Things Behind The Sun
# 236951                    walking in the snow
#
#        master_metadata_album_artist_name  \
# 290288                         JPEGMAFIA
# 76864                           slowthai
# 122359                     Devon Hendryx
# 30514            Black Country, New Road
# 72465              The Smashing Pumpkins
# 309237                    The Avalanches
# 174470                 Father John Misty
# 194425                            Bladee
# 292824                        Nick Drake
# 236951                    Run The Jewels
#
#               master_metadata_album_album_name  \
# 290288                                     EP!
# 76864                                     UGLY
# 122359                           JOECHILLWORLD
# 30514                       Ants From Up There
# 72465   Mellon Collie And The Infinite Sadness
# 309237                        Since I Left You
# 174470                           Mahashmashana
# 194425                            Cold Visions
# 292824                               Pink Moon
# 236951                                    RTJ4
#
#                            spotify_track_uri episode_name episode_show_name  \
# 290288  spotify:track:7yqmlcaGAE0Q6nZ9cNZ7NE          NaN               NaN
# 76864   spotify:track:6srSZ98GEz495b0ejEIVGl          NaN               NaN
# 122359  spotify:track:7p4QiDvvgQLmvqKQUNFUsN          NaN               NaN
# 30514   spotify:track:3k2kIiJqUiIP49iUcOLpWT          NaN               NaN
# 72465   spotify:track:5QLHGv0DfpeXLNFo7SFEy1          NaN               NaN
# 309237  spotify:track:4WVUtbd7CL38fVdIQVN3fk          NaN               NaN
# 174470  spotify:track:0VOCrdsydNicYcSTrjkk1f          NaN               NaN
# 194425  spotify:track:2uUzWTAtMLbwu8YL1C53sN          NaN               NaN
# 292824  spotify:track:2s89qv9maW8RMCoaxtvNtn          NaN               NaN
# 236951  spotify:track:2pVvB487ZwqdzTxEvEEors          NaN               NaN
#
#         ... audiobook_uri  audiobook_chapter_uri  audiobook_chapter_title  \
# 290288  ...           NaN                    NaN                      NaN
# 76864   ...           NaN                    NaN                      NaN
# 122359  ...           NaN                    NaN                      NaN
# 30514   ...           NaN                    NaN                      NaN
# 72465   ...           NaN                    NaN                      NaN
# 309237  ...           NaN                    NaN                      NaN
# 174470  ...           NaN                    NaN                      NaN
# 194425  ...           NaN                    NaN                      NaN
# 292824  ...           NaN                    NaN                      NaN
# 236951  ...           NaN                    NaN                      NaN
#
#         reason_start                    reason_end shuffle skipped  offline  \
# 290288        fwdbtn                        fwdbtn    True   False    False
# 76864      trackdone                        fwdbtn    True    True    False
# 122359     trackdone  unexpected-exit-while-paused    True   False    False
# 30514         remote                     trackdone    True   False    False
# 72465        appload                       unknown    True   False    False
# 309237        fwdbtn                       backbtn    True   False    False
# 174470     trackdone                        fwdbtn    True    True    False
# 194425     trackdone                        fwdbtn    True    True    False
# 292824     trackdone                     trackdone    True   False    False
# 236951       playbtn                     trackdone    True   False    False
#
#         offline_timestamp  incognito_mode
# 290288                NaN           False
# 76864        1.677858e+09           False
# 122359       1.711780e+09           False
# 30514                 NaN           False
# 72465        1.674843e+09           False
# 309237                NaN           False
# 174470       1.754642e+09           False
# 194425       1.759090e+09           False
# 292824                NaN           False
# 236951                NaN           False
#
# [10 rows x 22 columns]

# %%
# drop all podcast and audiobook rows
fullHistory = fullHistory[~fullHistory["episode_name"].notna()]
fullHistory = fullHistory[~fullHistory["audiobook_uri"].notna()]

# drop podcasts and audiobooks columns
fullHistory = fullHistory.drop(
    columns=[
        "episode_name",
        "episode_show_name",
        "spotify_episode_uri",
        "audiobook_title",
        "audiobook_chapter_uri",
        "audiobook_uri",
        "audiobook_chapter_title",
    ]
)

# %%
fullHistory.sample(10)
# Out:
#                           ts                 platform  ms_played conn_country  \
# 249397  2021-03-06T20:25:29Z    iOS 14.4 (iPhone13,2)     211440           GB
# 284443  2021-08-04T13:27:00Z    iOS 14.6 (iPhone13,2)     251946           GB
# 134964  2024-06-25T21:28:50Z                      ios      66510           GB
# 275340  2021-06-25T02:06:39Z    iOS 14.6 (iPhone13,2)     316640           GB
# 213025  2020-04-09T22:44:44Z   iOS 12.4.5 (iPhone7,2)       6826           GB
# 21421   2022-01-27T19:07:46Z  iOS 15.2.1 (iPhone13,2)        859           GB
# 241171  2021-01-25T13:03:37Z    iOS 14.3 (iPhone13,2)     255386           GB
# 239813  2021-01-19T21:42:47Z    iOS 14.3 (iPhone13,2)       2275           GB
# 204951  2020-01-18T18:30:13Z   iOS 12.4.4 (iPhone6,2)       3227           GB
# 87336   2023-05-28T12:30:19Z                      ios       2281           GB
#
#             master_metadata_track_name master_metadata_album_artist_name  \
# 249397                       Stay Away                           Nirvana
# 284443                  when you sleep               my bloody valentine
# 134964                 Spring breakers                        Charli xcx
# 275340                        The Moon                   The Microphones
# 213025                 Come As You Are                           Nirvana
# 21421                           Candle                       Sonic Youth
# 241171                            Nude                         Radiohead
# 239813   In the Aeroplane Over the Sea                Neutral Milk Hotel
# 204951  ¿Viva La Gloria? (Little Girl)                         Green Day
# 87336                         Operator                        Yves Tumor
#
#                          master_metadata_album_album_name  \
# 249397                                          Nevermind
# 284443                                           loveless
# 134964  Brat and it’s the same but there’s three more ...
# 275340                                    The Glow, Pt. 2
# 213025                                          Nevermind
# 21421         Daydream Nation (Remastered Original Album)
# 241171                                        In Rainbows
# 239813                      In the Aeroplane Over the Sea
# 204951                             21st Century Breakdown
# 87336   Praise A Lord Who Chews But Which Does Not Con...
#
#                            spotify_track_uri reason_start reason_end  shuffle  \
# 249397  spotify:track:0w7k0ZhHzkfEBsDmwp49xA    trackdone  trackdone     True
# 284443  spotify:track:2KylN9C0wNbzLgZNTG9oiU    trackdone  trackdone    False
# 134964  spotify:track:3dk7WaeS0y0JG0OMd0FVcg    trackdone    endplay     True
# 275340  spotify:track:4pbEwQiDjPln3oYlijXuOE    trackdone  trackdone     True
# 213025  spotify:track:2RsAajgo0g7bMCHxwH3Sk0     clickrow    endplay    False
# 21421   spotify:track:7j8qXNeUNts3YxZ0hC1pi8      playbtn    endplay     True
# 241171  spotify:track:35YyxFpE0ZTOoqFx5bADW8      playbtn  trackdone    False
# 239813  spotify:track:4OciRObYGzPzlU40U7YRc8      playbtn    endplay    False
# 204951  spotify:track:2mnk1GHN0XmznKiucY4ZW4     clickrow     fwdbtn    False
# 87336   spotify:track:6wsmCMlFGX4jOko2I3bUtb    trackdone     fwdbtn     True
#
#         skipped  offline  offline_timestamp  incognito_mode
# 249397    False    False                NaN           False
# 284443    False    False                NaN           False
# 134964     True    False       1.719351e+09           False
# 275340    False    False                NaN           False
# 213025    False    False                NaN           False
# 21421     False    False                NaN           False
# 241171    False    False                NaN           False
# 239813    False    False                NaN           False
# 204951    False     True       1.579371e+12           False
# 87336      True    False       1.685277e+09           False

# %%
# drop irrelevant columns
fullHistory = fullHistory.drop(
    columns=[
        "platform",
        "spotify_track_uri",
        "shuffle",
        "offline",
        "offline_timestamp",
        "incognito_mode"
    ]
)

# %%
fullHistory.to_csv("./Spotify Extended Streaming History/cleaned-history.csv", index=False)
